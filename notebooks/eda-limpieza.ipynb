# %% [markdown]
# # EDA y Limpieza de Datos

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('../data/raw/listings.csv')
gdf_neighbourhoods = gpd.read_file("../data/raw/neighbourhoods.geojson")

columnas_esenciales = [
    # Identificación
    'name', 
    # Host
    'host_id', 'host_name',
    # Caracterización
    'property_type', 'room_type', 'bedrooms', 'beds', 'bathrooms', 'accommodates', 'description',
    # Precio
    'price', 
    # Ubicación
    'neighbourhood_cleansed', 'latitude', 'longitude', 
    # Actividad
    'number_of_reviews', 'last_review', 'minimum_nights', 'availability_365', 'review_scores_rating'
]

df = df[columnas_esenciales]
df.head()
# Out:
#                                               name  ...  review_scores_rating
# 0                     luminosa mansarda con balcón  ...                  5.00
# 1  Cómoda habitación bien ubicada con baño privado  ...                  5.00
# 2               Cómodo departamento Cerca de Metro  ...                  4.74
# 3                 Acogedor Dormitorio + baño priv.  ...                   NaN
# 4                 Departamento frente a est. metro  ...                   NaN
#
# [5 rows x 19 columns]
