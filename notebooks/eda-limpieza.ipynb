# %% [markdown]
# # EDA y Limpieza de Datos

# %%
# Creación del subset con solo 21 columnas "relevantes"

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('../data/raw/listings.csv')
gdf_neighbourhoods = gpd.read_file("../data/raw/neighbourhoods.geojson")

columnas_esenciales = [
    # Identificación
    'name', 
    # Host
    'host_id', 'host_name',
    # Caracterización
    'property_type', 'room_type', 'bedrooms', 'beds', 'bathrooms', 'bathrooms_text', 'accommodates', 'description',
    # Precio
    'price', 
    # Ubicación
    'neighbourhood_cleansed', 'latitude', 'longitude', 
    # Actividad
    'number_of_reviews', 'last_review', 'minimum_nights', 'availability_365', 'review_scores_rating'
]

df_subset = df[columnas_esenciales]

df_subset.to_csv('../data/processed/listings_subset.csv')
